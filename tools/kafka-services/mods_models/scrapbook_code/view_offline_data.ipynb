# %%
import pandas as pd

df = pd.read_csv('buffer-all.tsv', sep='\t')
df = df.set_index('ts')
df.index = pd.to_datetime(df.index)

display(df)
df.describe()
# Out:
#                      conn_count_uid_in  conn_count_uid_internal  \
# ts
# 2021-03-11 10:40:00            11353.0                   2736.0
# 2021-03-11 10:50:00            11632.0                   3043.0
# 2021-03-11 11:00:00             9488.0                   2396.0
# 2021-03-11 11:10:00            12695.0                   2543.0
# 2021-03-11 11:20:00            10564.0                   2881.0
# ...                                ...                      ...
# 2021-03-21 19:10:00            16977.0                   1971.0
# 2021-03-21 19:20:00            15615.0                   2612.0
# 2021-03-21 19:30:00            16063.0                   2510.0
# 2021-03-21 19:40:00            15493.0                   2520.0
# 2021-03-21 19:50:00            18009.0                   2628.0
#
#                      conn_count_uid_out  conn_mean_duration_in  \
# ts
# 2021-03-11 10:40:00              2526.0               8.031479
# ...
